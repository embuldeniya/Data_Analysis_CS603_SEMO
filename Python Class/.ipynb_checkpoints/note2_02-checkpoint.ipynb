# %%
"""
- Indentation, not braces
- object model: Every number, string, data structure, function, class, module, and so on - a Python object. 
Each object has an associated type(e.g., string or function) and internal data. 
- assignment operator for variable: lv = right side object #create a reference to the object on the righthand side
- pass objects as arguments to a function
- Variables are names for objects within a particular namespace; the type information is stored in the object itself.
"""
a = [1, 2,3]
b = a #b reference to a, both point to the same list
b.append(5)
print(a)
def change_list(pList, item): #pass by reference
    pList.append(item)
change_list(a, 6)
print(a)
print(b)

x = 5
print(type(x)) #type is stored in object, not variable
x = "hello"
print(type(x)) #type is stored in object, not variable
print(isinstance(x, int)) #check that an object is an instance of a particular type
print(isinstance(x, (int, str)))
"""
Attributes and methods
a.<Press Tab>: will list all attributes and methods associated with a
"""
#x.
"""
check if an object is iterable
"""
def isiterable(obj):    
    try:        
        iter(obj)        
        return True    
    except TypeError: # not iterable        
        return False
print("x is iterable?", isiterable(x))
print("a is iterable?", isiterable(a))
if not isinstance(x, list) and isiterable(x):    
    x = list(x)
print("str to list", x)
"""
import some_module as sm
from some_module import PI as pi, g as gf
"""
"""
is and is not: check if two references are the same object
==: check if two copies the same
"""
b = a
c = list(a)
print(b is a)
print(c is a)
print(c == a)
"""
Most objects in Python, such as lists, dicts, NumPy arrays, and most user-defined types (classes), are mutable.
Others, like strings and tuples, are immutable.
Python along with its standard library has a small set of built-in types for handling numerical data, strings, 
boolean (True or False) values, and dates and time. 
These “single value” types are sometimes called scalar types
preface the leading quote of the string with r, which means that the characters should be interpreted as is
"""
s = r'this\has\no\special\characters'
print(s)
"""
Bytes and Unicode
"""
val = "español"
print(val)
print(val, 'type: ', type(val))
val_utf8 = val.encode('utf-8')
print(val_utf8, 'type: ', type(val_utf8))
print(val_utf8.decode('utf-8'))
# Out:
# [1, 2, 3, 5]
# [1, 2, 3, 5, 6]
# [1, 2, 3, 5, 6]
# <class 'int'>
# <class 'str'>
# False
# True
# x is iterable? True
# a is iterable? True
# str to list ['h', 'e', 'l', 'l', 'o']
# True
# False
# True
# this\has\no\special\characters
# español
# español type:  <class 'str'>
# b'espa\xc3\xb1ol' type:  <class 'bytes'>
# español
