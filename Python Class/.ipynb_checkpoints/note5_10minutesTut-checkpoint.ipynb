# %% [markdown]
# ## Pandas quickstart
# - 10 minute quickstart from official pandas website: https://pandas.pydata.org/pandas-docs/stable/10min.html
# - a second quick review for pandas: https://nbviewer.jupyter.org/gist/manujeevanprakash/996d18985be612072ee0

# %% [markdown]
# ### Create series: passing a list of values, letting pandas create a default integer index

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
s = pd.Series([1,3,5,np.nan,6,8])

# %% [markdown]
# series is a one-dimensional labeled array

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# There are two ways through which we can access element of series, they are :
#
# Accessing Element from Series with Position
# Accessing Element Using Label (index)

# %%
# creating simple array
data = np.array(['1','2','3','5','6','7'])
ser = pd.Series(data,index=['A','B','C','D','E','F'])  
  
# accessing an element using index label
print(ser['B'])
# Out:
# 2

# %%
# making data frame  
df = pd.read_csv("nba.csv")  
# series is one column of a dataframe   
ser = pd.Series(df['Name']) 
data = ser.head(10)
data
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# 5     Amir Johnson
# 6    Jordan Mickey
# 7     Kelly Olynyk
# 8     Terry Rozier
# 9     Marcus Smart
# Name: Name, dtype: object

# %%
data[3:6]
# Out:
# 3      R.J. Hunter
# 4    Jonas Jerebko
# 5     Amir Johnson
# Name: Name, dtype: object

# %% [markdown]
# .loc[ ] function selects data by refering the explicit index

# %%
data.loc[3:6]
# Out:
# 3      R.J. Hunter
# 4    Jonas Jerebko
# 5     Amir Johnson
# 6    Jordan Mickey
# Name: Name, dtype: object

# %% [markdown]
#  .iloc[ ] allows us to retrieve data by position. In order to do that, we’ll need to specify the positions of the data that we want. The df.iloc indexer is very similar to df.loc but only uses integer locations to make its selections.

# %%
data.iloc[3:6]
# Out:
# 3      R.J. Hunter
# 4    Jonas Jerebko
# 5     Amir Johnson
# Name: Name, dtype: object

# %% [markdown]
# In conversion operation we perform various operation like changing datatype of series, changing a series to list etc. In order to perform conversion operation we have various function which help in conversion like .astype(), .tolist() etc.

# %%
# reading csv file from url  
data = pd.read_csv("nba.csv") 
    
# dropping null value columns to avoid errors 
data.dropna(inplace = True) 
   
# storing dtype before converting 
before = data.dtypes 
   
# converting dtypes using astype 
data["Salary"]= data["Salary"].astype(int) 
data["Number"]= data["Number"].astype(str) 
   
# storing dtype after converting 
after = data.dtypes 
   
# printing to compare 
print("BEFORE CONVERSION\n", before, "\n") 
print("AFTER CONVERSION\n", after, "\n")
# Out:
# BEFORE CONVERSION
#  Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object
#
# AFTER CONVERSION
#  Name         object
# Team         object
# Number       object
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary        int32
# dtype: object

# %% [markdown]
# ### Creating a DataFrame by passing a NumPy array, with a datetime index and labeled columns

# %%
dates = pd.date_range('20130101', periods=6)
dates
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.804197  0.479630 -2.439085 -0.644801
# 2013-01-02  0.523665  0.800653  0.764419  0.320271
# 2013-01-03  0.918491  1.265635 -0.687919 -0.476874
# 2013-01-04  0.230421 -0.486204 -0.947892  2.248399
# 2013-01-05  0.073374 -0.923484 -0.644578 -1.802593
# 2013-01-06  2.272343  1.239026  0.350081  0.255572

# %% [markdown]
# ### Creating a DataFrame by passing a dict of objects that can be converted to series-like

# %%
df2 = pd.DataFrame({ 'A' : 1.,
                     'B' : pd.Timestamp('20130102'),
                     'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
                     'D' : np.array([3] * 4,dtype='int32'),
                     'E' : pd.Categorical(["test","train","test","train"]),
                     'F' : 'foo' })
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %% [markdown]
# ### view the top and bottom rows of the frame

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01 -0.804197  0.479630 -2.439085 -0.644801
# 2013-01-02  0.523665  0.800653  0.764419  0.320271
# 2013-01-03  0.918491  1.265635 -0.687919 -0.476874
# 2013-01-04  0.230421 -0.486204 -0.947892  2.248399
# 2013-01-05  0.073374 -0.923484 -0.644578 -1.802593

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04  0.230421 -0.486204 -0.947892  2.248399
# 2013-01-05  0.073374 -0.923484 -0.644578 -1.802593
# 2013-01-06  2.272343  1.239026  0.350081  0.255572

# %% [markdown]
# ### Display the index, columns, and the underlying NumPy data

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[-0.80419711,  0.47963034, -2.43908492, -0.64480073],
#        [ 0.52366484,  0.80065276,  0.76441925,  0.32027147],
#        [ 0.91849104,  1.26563478, -0.68791881, -0.47687362],
#        [ 0.23042081, -0.48620395, -0.94789158,  2.24839853],
#        [ 0.073374  , -0.92348357, -0.64457777, -1.802593  ],
#        [ 2.27234291,  1.23902596,  0.35008112,  0.25557187]])

# %% [markdown]
# ### describe() shows a quick statistic summary of your data

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.535683  0.395876 -0.600829 -0.016671
# std    1.026145  0.911813  1.120470  1.350114
# min   -0.804197 -0.923484 -2.439085 -1.802593
# 25%    0.112636 -0.244745 -0.882898 -0.602819
# 50%    0.377043  0.640142 -0.666248 -0.110651
# 75%    0.819784  1.129433  0.101416  0.304097
# max    2.272343  1.265635  0.764419  2.248399

# %% [markdown]
# NumPy arrays have one dtype for the entire array, while pandas DataFrames have one dtype per column. When you call DataFrame.to_numpy(), pandas will find the NumPy dtype that can hold all of the dtypes in the DataFrame. This may end up being object, which requires casting every value to a Python object and is relatively expensive

# %% [markdown]
# ### Transposing your data

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A   -0.804197    0.523665    0.918491    0.230421    0.073374    2.272343
# B    0.479630    0.800653    1.265635   -0.486204   -0.923484    1.239026
# C   -2.439085    0.764419   -0.687919   -0.947892   -0.644578    0.350081
# D   -0.644801    0.320271   -0.476874    2.248399   -1.802593    0.255572

# %% [markdown]
# ### Sorting by an axis

# %%
df.sort_index(axis=1, ascending=False)
#df.sort_index(axis=0, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01 -0.644801 -2.439085  0.479630 -0.804197
# 2013-01-02  0.320271  0.764419  0.800653  0.523665
# 2013-01-03 -0.476874 -0.687919  1.265635  0.918491
# 2013-01-04  2.248399 -0.947892 -0.486204  0.230421
# 2013-01-05 -1.802593 -0.644578 -0.923484  0.073374
# 2013-01-06  0.255572  0.350081  1.239026  2.272343

# %% [markdown]
# ### Sorting by values

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2013-01-05  0.073374 -0.923484 -0.644578 -1.802593
# 2013-01-04  0.230421 -0.486204 -0.947892  2.248399
# 2013-01-01 -0.804197  0.479630 -2.439085 -0.644801
# 2013-01-02  0.523665  0.800653  0.764419  0.320271
# 2013-01-06  2.272343  1.239026  0.350081  0.255572
# 2013-01-03  0.918491  1.265635 -0.687919 -0.476874

# %% [markdown]
# ### optimized pandas data access methods: .at, .iat, .loc and .iloc.
# <p>Getting</p>
# <p>Selecting a single column, which yields a Series, equivalent to df.A:</p>

# %%
df[['A','B']]
# Out:
#                    A         B
# 2013-01-01 -0.804197  0.479630
# 2013-01-02  0.523665  0.800653
# 2013-01-03  0.918491  1.265635
# 2013-01-04  0.230421 -0.486204
# 2013-01-05  0.073374 -0.923484
# 2013-01-06  2.272343  1.239026

# %% [markdown]
# <p>
# Selecting via [], which slices the rows
# </p>

# %%
df[0:3]
df['20130102':'20130104']
# Out:
#                    A         B         C         D
# 2013-01-02  0.523665  0.800653  0.764419  0.320271
# 2013-01-03  0.918491  1.265635 -0.687919 -0.476874
# 2013-01-04  0.230421 -0.486204 -0.947892  2.248399

# %% [markdown]
# ### Selection by Label: getting a cross section using a label:

# %%
# making data frame from csv file
data = pd.read_csv("nba.csv", index_col ="Name")
 
# retrieving row by loc method
first = data.loc["Avery Bradley"]
second = data.loc["R.J. Hunter"]

print(first, "\n\n\n", second)
# Out:
# Team        Boston Celtics
# Number                   0
# Position                PG
# Age                     25
# Height                 6-2
# Weight                 180
# College              Texas
# Salary         7.73034e+06
# Name: Avery Bradley, dtype: object
#
#
#  Team        Boston Celtics
# Number                  28
# Position                SG
# Age                     22
# Height                 6-5
# Weight                 185
# College      Georgia State
# Salary         1.14864e+06
# Name: R.J. Hunter, dtype: object

# %%
print(df)
print(dates[0])
df.loc[dates[0]]
# Out:
#                    A         B         C         D
# 2013-01-01 -0.804197  0.479630 -2.439085 -0.644801
# 2013-01-02  0.523665  0.800653  0.764419  0.320271
# 2013-01-03  0.918491  1.265635 -0.687919 -0.476874
# 2013-01-04  0.230421 -0.486204 -0.947892  2.248399
# 2013-01-05  0.073374 -0.923484 -0.644578 -1.802593
# 2013-01-06  2.272343  1.239026  0.350081  0.255572
# 2013-01-01 00:00:00
# A   -0.804197
# B    0.479630
# C   -2.439085
# D   -0.644801
# Name: 2013-01-01 00:00:00, dtype: float64

# %% [markdown]
# ### Selecting on a multi-axis by label

# %%
df.loc[:,['A','B']]
# Out:
#                    A         B
# 2013-01-01 -0.804197  0.479630
# 2013-01-02  0.523665  0.800653
# 2013-01-03  0.918491  1.265635
# 2013-01-04  0.230421 -0.486204
# 2013-01-05  0.073374 -0.923484
# 2013-01-06  2.272343  1.239026

# %% [markdown]
# ### using label slicing, both endpoints are included

# %%
df.loc['20130102':'20130104',['A','B']]
# Out:
#                    A         B
# 2013-01-02  0.523665  0.800653
# 2013-01-03  0.918491  1.265635
# 2013-01-04  0.230421 -0.486204

# %% [markdown]
# ### Reduction in the dimensions of the returned object

# %%
df.loc['20130102',['A','B']]
# Out:
# A    0.523665
# B    0.800653
# Name: 2013-01-02 00:00:00, dtype: float64

# %% [markdown]
# ### getting a scalar value

# %%
df.loc[dates[0],'A']
# Out:
# -0.8041971093918426

# %% [markdown]
# ### .at for fast access to a scalar

# %%
df.at[dates[0],'A']
# Out:
# -0.8041971093918426

# %% [markdown]
# ## Selection by position
# ### Select via the position of the passed integers

# %%
df.iloc[2]
# Out:
# A    0.918491
# B    1.265635
# C   -0.687919
# D   -0.476874
# Name: 2013-01-03 00:00:00, dtype: float64

# %% [markdown]
# #### using integer slices

# %%
df.iloc[3:5,0:2]
# Out:
#                    A         B
# 2013-01-04  0.230421 -0.486204
# 2013-01-05  0.073374 -0.923484

# %% [markdown]
# ### using lists of integer position locations

# %%
df.iloc[[1,2,4],[0,2]]
# Out:
#                    A         C
# 2013-01-02  0.523665  0.764419
# 2013-01-03  0.918491 -0.687919
# 2013-01-05  0.073374 -0.644578

# %% [markdown]
# ### slicing rows explicitly

# %%
df.iloc[1:3,:]
# Out:
#                    A         B         C         D
# 2013-01-02  0.523665  0.800653  0.764419  0.320271
# 2013-01-03  0.918491  1.265635 -0.687919 -0.476874

# %% [markdown]
# ### slicing columns explicitly

# %%
df.iloc[:,1:3]
# Out:
#                    B         C
# 2013-01-01  0.479630 -2.439085
# 2013-01-02  0.800653  0.764419
# 2013-01-03  1.265635 -0.687919
# 2013-01-04 -0.486204 -0.947892
# 2013-01-05 -0.923484 -0.644578
# 2013-01-06  1.239026  0.350081

# %% [markdown]
# ### getting a scalar, for fast access, using .iat

# %%
df.iloc[1,1]
df.iat[1,1]
# Out:
# 0.8006527553803532

# %% [markdown]
# ## Boolean Indexing
# ### Using a single column’s values to select data

# %%
df[df.A > 0]
# Out:
#                    A         B         C         D
# 2013-01-02  0.523665  0.800653  0.764419  0.320271
# 2013-01-03  0.918491  1.265635 -0.687919 -0.476874
# 2013-01-04  0.230421 -0.486204 -0.947892  2.248399
# 2013-01-05  0.073374 -0.923484 -0.644578 -1.802593
# 2013-01-06  2.272343  1.239026  0.350081  0.255572

# %% [markdown]
# #### Selecting values from a DataFrame where a boolean condition is met.

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01       NaN  0.479630       NaN       NaN
# 2013-01-02  0.523665  0.800653  0.764419  0.320271
# 2013-01-03  0.918491  1.265635       NaN       NaN
# 2013-01-04  0.230421       NaN       NaN  2.248399
# 2013-01-05  0.073374       NaN       NaN       NaN
# 2013-01-06  2.272343  1.239026  0.350081  0.255572

# %% [markdown]
# ### Using the isin() method for filtering

# %%
df2 = df.copy()
df2['E'] = ['one', 'one','two','three','four','three']
df2[df2['E'].isin(['two','four'])]
# Out:
#                    A         B         C         D     E
# 2013-01-03  0.918491  1.265635 -0.687919 -0.476874   two
# 2013-01-05  0.073374 -0.923484 -0.644578 -1.802593  four

# %% [markdown]
# ## Setting
# ### Setting a new column automatically aligns the data by the indexes

# %%
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range('20130102', periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df['F'] = s1
df
# Out:
#                    A         B         C         D    F
# 2013-01-01 -0.804197  0.479630 -2.439085 -0.644801  NaN
# 2013-01-02  0.523665  0.800653  0.764419  0.320271  1.0
# 2013-01-03  0.918491  1.265635 -0.687919 -0.476874  2.0
# 2013-01-04  0.230421 -0.486204 -0.947892  2.248399  3.0
# 2013-01-05  0.073374 -0.923484 -0.644578 -1.802593  4.0
# 2013-01-06  2.272343  1.239026  0.350081  0.255572  5.0

# %% [markdown]
# #### Setting values by label

# %%
df.at[dates[0],'A'] = 0
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.000000  0.479630 -2.439085 -0.644801  NaN
# 2013-01-02  0.523665  0.800653  0.764419  0.320271  1.0
# 2013-01-03  0.918491  1.265635 -0.687919 -0.476874  2.0
# 2013-01-04  0.230421 -0.486204 -0.947892  2.248399  3.0
# 2013-01-05  0.073374 -0.923484 -0.644578 -1.802593  4.0
# 2013-01-06  2.272343  1.239026  0.350081  0.255572  5.0

# %% [markdown]
# ### Setting values by position

# %%
df.iat[0,1] = 0
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.000000  0.000000 -2.439085 -0.644801  NaN
# 2013-01-02  0.523665  0.800653  0.764419  0.320271  1.0
# 2013-01-03  0.918491  1.265635 -0.687919 -0.476874  2.0
# 2013-01-04  0.230421 -0.486204 -0.947892  2.248399  3.0
# 2013-01-05  0.073374 -0.923484 -0.644578 -1.802593  4.0
# 2013-01-06  2.272343  1.239026  0.350081  0.255572  5.0

# %% [markdown]
# ### setting by assigning with a NumPy array

# %%
df.loc[:,'D'] = np.array([5] * len(df))
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -2.439085  5  NaN
# 2013-01-02  0.523665  0.800653  0.764419  5  1.0
# 2013-01-03  0.918491  1.265635 -0.687919  5  2.0
# 2013-01-04  0.230421 -0.486204 -0.947892  5  3.0
# 2013-01-05  0.073374 -0.923484 -0.644578  5  4.0
# 2013-01-06  2.272343  1.239026  0.350081  5  5.0

# %% [markdown]
# ### where operation with setting

# %%
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -2.439085 -5  NaN
# 2013-01-02 -0.523665 -0.800653 -0.764419 -5 -1.0
# 2013-01-03 -0.918491 -1.265635 -0.687919 -5 -2.0
# 2013-01-04 -0.230421 -0.486204 -0.947892 -5 -3.0
# 2013-01-05 -0.073374 -0.923484 -0.644578 -5 -4.0
# 2013-01-06 -2.272343 -1.239026 -0.350081 -5 -5.0

# %% [markdown]
# ## Missing data
# <p>
# pandas primarily uses the value np.nan to represent missing data. It is by default not included in computations.
#
# Reindexing allows you to change/add/delete the index on a specified axis. This returns a copy of the data.
# </p>

# %%
#print(df)
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1.loc[dates[0]:dates[1],'E'] = 1
df1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000 -2.439085  5  NaN  1.0
# 2013-01-02  0.523665  0.800653  0.764419  5  1.0  1.0
# 2013-01-03  0.918491  1.265635 -0.687919  5  2.0  NaN
# 2013-01-04  0.230421 -0.486204 -0.947892  5  3.0  NaN

# %% [markdown]
# ### To drop any rows that have missing data. only view, not on original data

# %%
df1.dropna(how='any')
# Out:
#                    A         B         C  D    F    E
# 2013-01-02  0.523665  0.800653  0.764419  5  1.0  1.0

# %% [markdown]
# ### Filling missing data

# %%
df1.fillna(value=100)
# Out:
#                    A         B         C  D      F      E
# 2013-01-01  0.000000  0.000000 -2.439085  5  100.0    1.0
# 2013-01-02  0.523665  0.800653  0.764419  5    1.0    1.0
# 2013-01-03  0.918491  1.265635 -0.687919  5    2.0  100.0
# 2013-01-04  0.230421 -0.486204 -0.947892  5    3.0  100.0

# %%
#To get the boolean mask where values are nan.
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %% [markdown]
# ## Operations
# ### Operations in general exclude missing data
# ### Performing a descriptive statistic

# %%
df.mean()
# Out:
# A    0.669716
# B    0.315938
# C   -0.600829
# D    5.000000
# F    3.000000
# dtype: float64

# %% [markdown]
# ### on the other axis

# %%
df.mean(1)
# Out:
# 2013-01-01    0.640229
# 2013-01-02    1.617747
# 2013-01-03    1.699241
# 2013-01-04    1.359265
# 2013-01-05    1.501063
# 2013-01-06    2.772290
# Freq: D, dtype: float64

# %% [markdown]
# ### Operating with objects that have different dimensionality and need alignment. In addition, pandas automatically broadcasts along the specified dimension.

# %%
s = pd.Series([1,3,5,np.nan,6,8], index=dates).shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis='index')
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -0.081509  0.265635 -1.687919  4.0  1.0
# 2013-01-04 -2.769579 -3.486204 -3.947892  2.0  0.0
# 2013-01-05 -4.926626 -5.923484 -5.644578  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %% [markdown]
# ### Applying functions to the data

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D     F
# 2013-01-01  0.000000  0.000000 -2.439085   5   NaN
# 2013-01-02  0.523665  0.800653 -1.674666  10   1.0
# 2013-01-03  1.442156  2.066288 -2.362584  15   3.0
# 2013-01-04  1.672577  1.580084 -3.310476  20   6.0
# 2013-01-05  1.745951  0.656600 -3.955054  25  10.0
# 2013-01-06  4.018294  1.895626 -3.604973  30  15.0

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    2.272343
# B    2.189118
# C    3.203504
# D    0.000000
# F    4.000000
# dtype: float64

# %%
#Histogramming
s = pd.Series(np.random.randint(0, 7, size=10))
s.value_counts()
# Out:
# 3    3
# 2    3
# 6    2
# 4    1
# 0    1
# dtype: int64

# %% [markdown]
# ## String Methods
# <p>
# Series is equipped with a set of string processing methods in the str attribute
# that make it easy to operate on each element of the array.
# Note that pattern-matching in str generally uses regular expressions by default
# </p>

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
# Define a dictionary containing employee data 
data = {'Name':['Jade', 'Prince', 'George', 'Bob'], 
        'Age':[27, 25, 22, 32], 
        'Address':['Nape', 'Kansas', 'Albany', 'Canada'], 
        'Qualification':['Ms', 'BS', 'BA', 'Phd']} 
 
# Convert the dictionary into DataFrame  
df = pd.DataFrame(data) 
    
# dropping null value columns to avoid errors 
df.dropna(inplace = True) 
    
# new data frame with split value columns 
df["Address"]= df["Address"].str.split("a", n = 1, expand = True) 
   
# df display 
print(df)
# Out:
#      Name  Age Address Qualification
# 0    Jade   27       N            Ms
# 1  Prince   25       K            BS
# 2  George   22     Alb            BA
# 3     Bob   32       C           Phd

# %%
# making copy of address column 
new = df["Address"].copy() 
# concatenating address with name column 
# overwriting name column 
df["Name"]= df["Name"].str.cat(new, sep =", ") 
   
# display 
print(df)
# Out:
#           Name  Age Address Qualification
# 0      Jade, N   27       N            Ms
# 1    Prince, K   25       K            BS
# 2  George, Alb   22     Alb            BA
# 3       Bob, C   32       C           Phd

# %%
# reading csv file from url
data = pd.read_csv("nba.csv")
 
# overwriting column with replaced value of age
data["Age"]= data["Age"].replace(25.0, "Twenty five")
 
# creating a filter for age column 
# where age = "Twenty five"
filter = data["Age"]=="Twenty five"
 
# printing only filtered columns
data.where(filter).dropna()
# Out:
#                     Name                    Team  Number Position  \
# 0          Avery Bradley          Boston Celtics     0.0       PG
# 1            Jae Crowder          Boston Celtics    99.0       SF
# 7           Kelly Olynyk          Boston Celtics    41.0        C
# 26       Thomas Robinson           Brooklyn Nets    41.0       PF
# 35      Cleanthony Early         New York Knicks    11.0       SF
# 44      Derrick Williams         New York Knicks    23.0       PF
# 47         Isaiah Canaan      Philadelphia 76ers     0.0       PG
# 48      Robert Covington      Philadelphia 76ers    33.0       SF
# 59       Hollis Thompson      Philadelphia 76ers    31.0       SG
# 71         Terrence Ross         Toronto Raptors    31.0       SF
# 79             Ian Clark   Golden State Warriors    21.0       SG
# 105          C.J. Wilcox    Los Angeles Clippers    30.0       SG
# 113           Ryan Kelly      Los Angeles Lakers     4.0       PF
# ...

# %%
# creating a series 
s = pd.Series(['a1', 'b2', 'c3'])
 
# Extracting a data
n= s.str.extract(r'([ab])(\d)')
 
print(n)
# Out:
#      0    1
# 0    a    1
# 1    b    2
# 2  NaN  NaN

# %%
# Extracting a data
n = s.str.extract(r'(?P<Geeks>[ab])(?P<For>\d)')
 
print(n)
# Out:
#   Geeks  For
# 0     a    1
# 1     b    2
# 2   NaN  NaN

# %% [markdown]
# ## Merge
# ## Concat
# <p>
# pandas provides various facilities for easily combining together Series, DataFrame, and Panel objects
# with various kinds of set logic for the indexes and relational algebra functionality in the case of
# join / merge-type operations.
# Concatenating pandas objects together with concat():
# </p>

# %%
df = pd.DataFrame(np.random.randn(10, 4))
pieces = [df[:3], df[3:7], df[7:]]
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  1.863709  1.823583 -1.436422  0.823440
# 1  2.352722 -0.298028 -0.070525  0.678666
# 2 -1.737364 -0.822161  1.464604  1.003871
# 3 -0.130883 -2.261731  1.267941  1.370812
# 4 -2.092158 -0.640864 -1.637091  0.315087
# 5 -0.947595 -0.746083 -0.097904  1.590133
# 6  1.120782  1.581467 -0.155961  1.928483
# 7  1.666592  0.481922  2.019127 -0.109563
# 8 -0.572760 -0.470118 -0.783949  0.390322
# 9 -0.212621  0.157009  0.564960 -0.030271

# %%
# Define a dictionary containing employee data 
data1 = {'Name':['Jade', 'Prince', 'George', 'Bob'], 
        'Age':[27, 25, 22, 32], 
        'Address':['Nape', 'Kansas', 'Albany', 'Canada'], 
        'Qualification':['Ms', 'BS', 'BA', 'Phd'],
        'Mobile No': [97, 91, 58, 76]} 

# Define a dictionary containing employee data 
data2 = {'Name':['George', 'Bob', 'Drew', 'Steve'], 
        'Age':[22, 32, 12, 52], 
        'Address':['Albany', 'Canada', 'Alabama', 'Iowa'], 
        'Qualification':['BA', 'Phd', 'BS', 'MA'],
        'Salary':[1000, 2000, 3000, 4000]} 

# Convert the dictionary into DataFrame  
df = pd.DataFrame(data1,index=[0, 1, 2, 3])
 
# Convert the dictionary into DataFrame  
df1 = pd.DataFrame(data2, index=[2, 3, 6, 7]) 
 
print(df, "\n\n", df1) 

# applying concat with axes
# join = 'inner'
res2 = pd.concat([df, df1], axis=1, join='inner')
 
res2
# Out:
#      Name  Age Address Qualification  Mobile No
# 0    Jade   27    Nape            Ms         97
# 1  Prince   25  Kansas            BS         91
# 2  George   22  Albany            BA         58
# 3     Bob   32  Canada           Phd         76
#
#       Name  Age  Address Qualification  Salary
# 2  George   22   Albany            BA    1000
# 3     Bob   32   Canada           Phd    2000
# 6    Drew   12  Alabama            BS    3000
# 7   Steve   52     Iowa            MA    4000
#      Name  Age Address Qualification  Mobile No    Name  Age Address  \
# 2  George   22  Albany            BA         58  George   22  Albany
# 3     Bob   32  Canada           Phd         76     Bob   32  Canada
#
#   Qualification  Salary
# 2            BA    1000
# 3           Phd    2000

# %%
# using a .concat for
# union of dataframe
res2 = pd.concat([df, df1], axis=1, sort=False)
 
res2
# Out:
#      Name   Age Address Qualification  Mobile No    Name   Age  Address  \
# 0    Jade  27.0    Nape            Ms       97.0     NaN   NaN      NaN
# 1  Prince  25.0  Kansas            BS       91.0     NaN   NaN      NaN
# 2  George  22.0  Albany            BA       58.0  George  22.0   Albany
# 3     Bob  32.0  Canada           Phd       76.0     Bob  32.0   Canada
# 6     NaN   NaN     NaN           NaN        NaN    Drew  12.0  Alabama
# 7     NaN   NaN     NaN           NaN        NaN   Steve  52.0     Iowa
#
#   Qualification  Salary
# 0           NaN     NaN
# 1           NaN     NaN
# 2            BA  1000.0
# 3           Phd  2000.0
# 6            BS  3000.0
# 7            MA  4000.0

# %%
# using join_axes
res3 = pd.concat([df, df1], axis=1, join_axes=[df.index])
 
res3
# Out:
#      Name  Age Address Qualification  Mobile No    Name   Age Address  \
# 0    Jade   27    Nape            Ms         97     NaN   NaN     NaN
# 1  Prince   25  Kansas            BS         91     NaN   NaN     NaN
# 2  George   22  Albany            BA         58  George  22.0  Albany
# 3     Bob   32  Canada           Phd         76     Bob  32.0  Canada
#
#   Qualification  Salary
# 0           NaN     NaN
# 1           NaN     NaN
# 2            BA  1000.0
# 3           Phd  2000.0

# %% [markdown]
# ## Join
# ### SQL style merges

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4, 5]})
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
# Define a dictionary containing employee data 
data1 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'key1': ['K0', 'K1', 'K0', 'K1'],
         'Name':['Jade', 'Prince', 'George', 'Bob'], 
        'Age':[27, 25, 22, 32]} 

# Define a dictionary containing employee data 
data2 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'key1': ['K0', 'K0', 'K0', 'K0'],
         'Address':['Nape', 'Kansas', 'Albany', 'Canada'], 
        'Qualification':['Ms', 'BS', 'BA', 'Phd']} 
 
# Convert the dictionary into DataFrame  
df = pd.DataFrame(data1)
 
# Convert the dictionary into DataFrame  
df1 = pd.DataFrame(data2) 

print(df, "\n\n", df1) 

# merging dataframe using multiple keys
res1 = pd.merge(df, df1, on=['key', 'key1'])
 
res1
# Out:
#   key key1    Name  Age
# 0  K0   K0    Jade   27
# 1  K1   K1  Prince   25
# 2  K2   K0  George   22
# 3  K3   K1     Bob   32
#
#    key key1 Address Qualification
# 0  K0   K0    Nape            Ms
# 1  K1   K0  Kansas            BS
# 2  K2   K0  Albany            BA
# 3  K3   K0  Canada           Phd
#   key key1    Name  Age Address Qualification
# 0  K0   K0    Jade   27    Nape            Ms
# 1  K2   K0  George   22  Albany            BA

# %%
# Merging dataframe using how in an argument: using keys from left frame
res = pd.merge(df, df1, how='left', on=['key', 'key1'])
 
res
# Out:
#   key key1    Name  Age Address Qualification
# 0  K0   K0    Jade   27    Nape            Ms
# 1  K1   K1  Prince   25     NaN           NaN
# 2  K2   K0  George   22  Albany            BA
# 3  K3   K1     Bob   32     NaN           NaN

# %%
# getting union  of keys
res2 = pd.merge(df, df1, how='outer', on=['key', 'key1'])
 
res2
# Out:
#   key key1    Name   Age Address Qualification
# 0  K0   K0    Jade  27.0    Nape            Ms
# 1  K1   K1  Prince  25.0     NaN           NaN
# 2  K2   K0  George  22.0  Albany            BA
# 3  K3   K1     Bob  32.0     NaN           NaN
# 4  K1   K0     NaN   NaN  Kansas            BS
# 5  K3   K0     NaN   NaN  Canada           Phd

# %%
# getting intersection of keys
res3 = pd.merge(df, df1, how='inner', on=['key', 'key1'])
 
res3
# Out:
#   key key1    Name  Age Address Qualification
# 0  K0   K0    Jade   27    Nape            Ms
# 1  K2   K0  George   22  Albany            BA

# %%
# Define a dictionary containing employee data 
data1 = {'Name':['Jade', 'Prince', 'George', 'Bob'], 
         'Age':[27, 25, 22, 32]} 

# Define a dictionary containing employee data 
data2 = {'Address':['Nape', 'Kansas', 'Albany', 'Canada'], 
         'Qualification':['Ms', 'BS', 'BA', 'Phd']} 

# Convert the dictionary into DataFrame  
df = pd.DataFrame(data1,index=['K0', 'K1', 'K2', 'K3'])
  
# Convert the dictionary into DataFrame  
df1 = pd.DataFrame(data2, index=['K0', 'K2', 'K3', 'K4']) 
 
print(df, "\n\n", df1) 

# joining dataframe: .join() function this function is used for combining the columns of 
# two potentially differently-indexed DataFrames into a single result DataFrame.
res = df.join(df1)
 
res
# Out:
#       Name  Age
# K0    Jade   27
# K1  Prince   25
# K2  George   22
# K3     Bob   32
#
#     Address Qualification
# K0    Nape            Ms
# K2  Kansas            BS
# K3  Albany            BA
# K4  Canada           Phd
#       Name  Age Address Qualification
# K0    Jade   27    Nape            Ms
# K1  Prince   25     NaN           NaN
# K2  George   22  Kansas            BS
# K3     Bob   32  Albany            BA

# %%
# getting union
res1 = df.join(df1, how='outer')
 
res1
# Out:
#       Name   Age Address Qualification
# K0    Jade  27.0    Nape            Ms
# K1  Prince  25.0     NaN           NaN
# K2  George  22.0  Kansas            BS
# K3     Bob  32.0  Albany            BA
# K4     NaN   NaN  Canada           Phd

# %%
# Define a dictionary containing employee data 
data1 = {'Name':['Jade', 'Prince', 'George', 'Bob'], 
         'Age':[27, 25, 22, 32],
         'Key':['K0', 'K1', 'K2', 'K3']} 

# Define a dictionary containing employee data 
data2 = {'Address':['Nape', 'Kansas', 'Albany', 'Canada'], 
         'Qualification':['Ms', 'BS', 'BA', 'Phd']} 

# Convert the dictionary into DataFrame  
df = pd.DataFrame(data1)
  
# Convert the dictionary into DataFrame  
df1 = pd.DataFrame(data2, index=['K0', 'K2', 'K3', 'K4'])

print(df, "\n\n", df1) 

# using on argument in join
res2 = df.join(df1, on='Key')
 
res2
# Out:
#      Name  Age Key
# 0    Jade   27  K0
# 1  Prince   25  K1
# 2  George   22  K2
# 3     Bob   32  K3
#
#     Address Qualification
# K0    Nape            Ms
# K2  Kansas            BS
# K3  Albany            BA
# K4  Canada           Phd
#      Name  Age Key Address Qualification
# 0    Jade   27  K0    Nape            Ms
# 1  Prince   25  K1     NaN           NaN
# 2  George   22  K2  Kansas            BS
# 3     Bob   32  K3  Albany            BA

# %%
# Define a dictionary containing employee data 
data1 = {'Name':['Jade', 'Prince', 'George'], 
         'Age':[27, 25, 22]} 

# Define a dictionary containing employee data 
data2 = {'Address':['Nape', 'Kansas', 'Albany', 'Canada'], 
         'Qualification':['Ms', 'BS', 'BA', 'Phd']} 

# Convert the dictionary into DataFrame  
df = pd.DataFrame(data1, index=pd.Index(['K0', 'K1', 'K2'], name='key'))
 
index = pd.MultiIndex.from_tuples([('K0', 'Y0'), ('K1', 'Y1'),
                                   ('K2', 'Y2'), ('K2', 'Y3')],
                                   names=['key', 'Y'])
  
# Convert the dictionary into DataFrame  
df1 = pd.DataFrame(data2, index= index) 
 
print(df, "\n\n", df1)

# joining singly indexed with multi indexed
result = df.join(df1, how='inner')
 
result
# Out:
#        Name  Age
# key
# K0     Jade   27
# K1   Prince   25
# K2   George   22
#
#         Address Qualification
# key Y
# K0  Y0    Nape            Ms
# K1  Y1  Kansas            BS
# K2  Y2  Albany            BA
#     Y3  Canada           Phd
#           Name  Age Address Qualification
# key Y
# K0  Y0    Jade   27    Nape            Ms
# K1  Y1  Prince   25  Kansas            BS
# K2  Y2  George   22  Albany            BA
#     Y3  George   22  Canada           Phd

# %% [markdown]
# ### Append rows to a dataframe

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A','B','C','D'])
s = df.iloc[3]
df.append(s, ignore_index=True)
# Out:
#           A         B         C         D
# 0 -0.853494  0.104622  0.389108  0.805285
# 1  1.809913  0.790310  0.471007  0.724151
# 2 -2.573750  0.890061 -0.718515 -0.802861
# 3 -1.208046 -0.287324 -0.053692 -1.446802
# 4  0.479070  1.076123  0.194453  1.037738
# 5  0.953808 -0.658615 -2.918821 -0.110849
# 6 -0.941915  0.904734 -1.129903  1.223417
# 7  1.558516 -0.517811  0.641536 -1.669966
# 8 -1.208046 -0.287324 -0.053692 -1.446802

# %% [markdown]
# ## Grouping - a process involving one or more of the following steps:
#
# - Splitting the data into groups based on some criteria
# - Applying a function to each group independently
# - Combining the results into a data structure

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
                   'B' : ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'], 
                   'C' : np.random.randn(8),
                   'D' : np.random.randn(8)})
df
# Out:
#      A      B         C         D
# 0  foo    one -0.268073 -0.451310
# 1  bar    one  1.340580  0.783491
# 2  foo    two -0.391914  0.749195
# 3  bar  three  0.663772  0.688815
# 4  foo    two  0.839957  0.602329
# 5  bar    two  0.193071 -1.471849
# 6  foo    one  1.101559 -0.030966
# 7  foo  three  0.069555 -0.414766

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar  2.197423  0.000457
# foo  1.351083  0.454482

# %% [markdown]
# ### Grouping by multiple columns forms a hierarchical index

# %%
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one    1.340580  0.783491
#     three  0.663772  0.688815
#     two    0.193071 -1.471849
# foo one    0.833485 -0.482276
#     three  0.069555 -0.414766
#     two    0.448043  1.351524

# %% [markdown]
# ## Reshaping
# ### stack
# ### *: unpacking iterable

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz', 'foo', 'foo', 'qux', 'qux'],
                    ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two']]))
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])
df
# Out:
#                      A         B
# first second
# bar   one     0.206703  1.573357
#       two     1.256568 -0.201050
# baz   one    -1.084665  1.281260
#       two     0.844889  0.160580
# foo   one     0.256156  0.437794
#       two    -0.643826  0.075389
# qux   one     1.276744 -0.397644
#       two     0.505794 -1.019255

# %%
df2 = df[:4]
df2
# Out:
#                      A         B
# first second
# bar   one     0.206703  1.573357
#       two     1.256568 -0.201050
# baz   one    -1.084665  1.281260
#       two     0.844889  0.160580

# %% [markdown]
# ### The stack() method “compresses” a level in the DataFrame’s columns

# %%
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A    0.206703
#                B    1.573357
#        two     A    1.256568
#                B   -0.201050
# baz    one     A   -1.084665
#                B    1.281260
#        two     A    0.844889
#                B    0.160580
# dtype: float64

# %% [markdown]
# ### With a “stacked” DataFrame or Series (having a MultiIndex as the index), the inverse operation of stack() is unstack(), which by default unstacks the last level

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one     0.206703  1.573357
#       two     1.256568 -0.201050
# baz   one    -1.084665  1.281260
#       two     0.844889  0.160580

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A  0.206703  1.256568
#       B  1.573357 -0.201050
# baz   A -1.084665  0.844889
#       B  1.281260  0.160580

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A  0.206703 -1.084665
#        B  1.573357  1.281260
# two    A  1.256568  0.844889
#        B -0.201050  0.160580

# %% [markdown]
# ### Pivot Tables
# allows to regroup and reshape data

# %%
df = pd.DataFrame({'A' : ['one', 'one', 'two', 'three'] * 3,
                   'B' : ['VA', 'VB', 'VC'] * 4,
                   'C' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                   'D' : np.random.randn(12),
                   'E' : np.random.randn(12)})
df
# Out:
#         A   B    C         D         E
# 0     one  VA  foo -0.073951 -0.523903
# 1     one  VB  foo -1.217069  0.964237
# 2     two  VC  foo -1.319159 -2.047076
# 3   three  VA  bar -1.592830  1.321686
# 4     one  VB  bar  1.068317  2.624155
# 5     one  VC  bar  1.210534 -0.603827
# 6     two  VA  foo  0.614100  0.918104
# 7   three  VB  foo -0.529859 -0.251971
# 8     one  VC  foo  0.955689  1.608767
# 9     one  VA  bar  0.120947 -0.685880
# 10    two  VB  bar -0.371655 -0.401986
# 11  three  VC  bar -1.025516 -2.570700

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C              bar       foo
# A     B
# one   VA  0.120947 -0.073951
#       VB  1.068317 -1.217069
#       VC  1.210534  0.955689
# three VA -1.592830       NaN
#       VB       NaN -0.529859
#       VC -1.025516       NaN
# two   VA       NaN  0.614100
#       VB -0.371655       NaN
#       VC       NaN -1.319159

# %%
pd.pivot_table(df, values='D',index=pd.Grouper(key='A'),columns='C') #mean of each group
# Out:
# C           bar       foo
# A
# one    0.799933 -0.111777
# two   -0.371655 -0.352530
# three -1.309173 -0.529859

# %% [markdown]
# ## Time Series
# <p>
# pandas has simple, powerful, and efficient functionality for performing resampling operations
# during frequency conversion (e.g., converting secondly data into 5-minutely data).
# </p>

# %%
rng = pd.date_range('1/1/2012', periods=10, freq='S')
rng
# Out:
# DatetimeIndex(['2012-01-01 00:00:00', '2012-01-01 00:00:01',
#                '2012-01-01 00:00:02', '2012-01-01 00:00:03',
#                '2012-01-01 00:00:04', '2012-01-01 00:00:05',
#                '2012-01-01 00:00:06', '2012-01-01 00:00:07',
#                '2012-01-01 00:00:08', '2012-01-01 00:00:09'],
#               dtype='datetime64[ns]', freq='S')

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
ts
# Out:
# 2012-01-01 00:00:00    298
# 2012-01-01 00:00:01    349
# 2012-01-01 00:00:02    453
# 2012-01-01 00:00:03    218
# 2012-01-01 00:00:04    224
# 2012-01-01 00:00:05    278
# 2012-01-01 00:00:06    117
# 2012-01-01 00:00:07    258
# 2012-01-01 00:00:08    374
# 2012-01-01 00:00:09    455
# Freq: S, dtype: int32

# %%
ts.resample('5Min').sum()
# Out:
# 2012-01-01    3024
# Freq: 5T, dtype: int32

# %%
#Time zone representation:
rng = pd.date_range('3/6/2012 00:00', periods=5, freq='D')
ts = pd.Series(np.random.randn(len(rng)), rng)
ts_utc = ts.tz_localize('UTC')
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00    1.972977
# 2012-03-07 00:00:00+00:00    0.323138
# 2012-03-08 00:00:00+00:00   -0.168668
# 2012-03-09 00:00:00+00:00    0.291928
# 2012-03-10 00:00:00+00:00   -1.514188
# Freq: D, dtype: float64

# %%
#Converting to another time zone:
ts_utc.tz_convert('US/Eastern')
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00    1.972977
# 2012-03-07 00:00:00+00:00    0.323138
# 2012-03-08 00:00:00+00:00   -0.168668
# 2012-03-09 00:00:00+00:00    0.291928
# 2012-03-10 00:00:00+00:00   -1.514188
# Freq: D, dtype: float64

# %%
#Converting between time span representations:
rng = pd.date_range('1/1/2012', periods=5, freq='M')
ts = pd.Series(np.random.randn(len(rng)), index=rng)
ts
# Out:
# 2012-01-31   -0.247569
# 2012-02-29    0.360971
# 2012-03-31    1.410340
# 2012-04-30   -0.969033
# 2012-05-31   -0.167555
# Freq: M, dtype: float64

# %%
ps = ts.to_period()
ps
# Out:
# 2012-01   -0.247569
# 2012-02    0.360971
# 2012-03    1.410340
# 2012-04   -0.969033
# 2012-05   -0.167555
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
ps
# Out:
# 2012-01   -0.247569
# 2012-02    0.360971
# 2012-03    1.410340
# 2012-04   -0.969033
# 2012-05   -0.167555
# Freq: M, dtype: float64

# %% [markdown]
# ### Converting between period and timestamp enables some convenient arithmetic functions to be used.
# <p>In the following example, we convert a quarterly frequency with year ending in November to
# 9am of the end of the month following the quarter end:
# </p>

# %%
prng = pd.period_range('1990Q1', '2000Q4', freq='Q-NOV')
ts = pd.Series(np.random.randn(len(prng)), prng)
ts.index = (prng.asfreq('M', 'e') + 1).asfreq('H', 's') + 9
ts.head()
# Out:
# 1990-03-01 09:00   -0.103362
# 1990-06-01 09:00   -2.029321
# 1990-09-01 09:00   -0.443673
# 1990-12-01 09:00   -0.603253
# 1991-03-01 09:00   -1.126102
# Freq: H, dtype: float64

# %% [markdown]
# ### Categoricals: pandas can include categorical data in a DataFrame.

# %%
df = pd.DataFrame({"id":[1,2,3,4,5,6], "raw_grade":['a', 'b', 'b', 'a', 'a', 'e']})
df["grade"] = df["raw_grade"].astype("category")
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): [a, b, e]

# %% [markdown]
# ### Rename the categories to more meaningful names (assigning to Series.cat.categories is inplace!).

# %%
df["grade"].cat.categories = ["very good", "good", "very bad"]
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (3, object): [very good, good, very bad]

# %% [markdown]
# ### Reorder the categories and simultaneously add the missing categories (methods under Series .cat return a new Series by default).

# %%
df["grade"] = df["grade"].cat.set_categories(["very bad", "bad", "medium", "good", "very good"])
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): [very bad, bad, medium, good, very good]

# %% [markdown]
# ### Sorting is per order in the categories, not lexical order.

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %% [markdown]
# ### Grouping by a categorical column also shows empty categories.

# %%
df.groupby("grade").size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %%
#Plotting
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()

# %% [markdown]
# ### On a DataFrame, the plot() method is a convenience to plot all of the columns with labels:

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=['A', 'B', 'C', 'D'])
df = df.cumsum()
plt.figure(); df.plot(); plt.legend(loc='best')

# %% [markdown]
# ### Getting data in/out with csv file

# %%
df.to_csv('foo.csv')
pd.read_csv('foo.csv')
# Out:
#      Unnamed: 0          A         B          C          D
# 0    2000-01-01   1.362679 -0.049286  -0.032228   0.708523
# 1    2000-01-02   1.583449  0.492326  -0.433146  -0.261986
# 2    2000-01-03   1.862538  1.307228  -1.757724  -0.158689
# 3    2000-01-04   3.065748 -0.447407  -1.172824  -0.694173
# 4    2000-01-05   2.859482  0.534329  -0.732441  -1.152969
# 5    2000-01-06   3.569029 -0.075315   0.467107  -3.282710
# 6    2000-01-07   4.098373  0.396356  -0.280112  -2.643024
# 7    2000-01-08   4.035274  1.187327  -0.626354  -2.805276
# 8    2000-01-09   2.995351  1.358176  -0.367052  -4.291214
# 9    2000-01-10   1.658753  1.823118  -0.488956  -4.888931
# 10   2000-01-11   3.057209  0.913850   0.967108  -3.838071
# 11   2000-01-12   2.718432 -0.596310  -1.810985  -4.665497
# 12   2000-01-13   2.343667 -1.159801  -2.858612  -5.649852
# 13   2000-01-14   2.755233 -2.949841  -3.647713  -4.424976
# 14   2000-01-15   4.285017 -3.654578  -3.083526  -4.672579
# ...

# %% [markdown]
# ### reading and writing to HDFStores

# %%
df.to_hdf('foo.h5','df')
pd.read_hdf('foo.h5','df')
# Out:
#                     A         B          C          D
# 2000-01-01   1.362679 -0.049286  -0.032228   0.708523
# 2000-01-02   1.583449  0.492326  -0.433146  -0.261986
# 2000-01-03   1.862538  1.307228  -1.757724  -0.158689
# 2000-01-04   3.065748 -0.447407  -1.172824  -0.694173
# 2000-01-05   2.859482  0.534329  -0.732441  -1.152969
# 2000-01-06   3.569029 -0.075315   0.467107  -3.282710
# 2000-01-07   4.098373  0.396356  -0.280112  -2.643024
# 2000-01-08   4.035274  1.187327  -0.626354  -2.805276
# 2000-01-09   2.995351  1.358176  -0.367052  -4.291214
# 2000-01-10   1.658753  1.823118  -0.488956  -4.888931
# 2000-01-11   3.057209  0.913850   0.967108  -3.838071
# 2000-01-12   2.718432 -0.596310  -1.810985  -4.665497
# 2000-01-13   2.343667 -1.159801  -2.858612  -5.649852
# 2000-01-14   2.755233 -2.949841  -3.647713  -4.424976
# 2000-01-15   4.285017 -3.654578  -3.083526  -4.672579
# 2000-01-16   3.510888 -3.369886  -3.236432  -2.716474
# ...

# %% [markdown]
# ### reading and writing to excel

# %%
df.to_excel('foo.xlsx', sheet_name='Sheet1')
pd.read_excel('foo.xlsx', 'Sheet1', index_col=None, na_values=['NA'])
# Out:
#                     A         B          C          D
# 2000-01-01   1.362679 -0.049286  -0.032228   0.708523
# 2000-01-02   1.583449  0.492326  -0.433146  -0.261986
# 2000-01-03   1.862538  1.307228  -1.757724  -0.158689
# 2000-01-04   3.065748 -0.447407  -1.172824  -0.694173
# 2000-01-05   2.859482  0.534329  -0.732441  -1.152969
# 2000-01-06   3.569029 -0.075315   0.467107  -3.282710
# 2000-01-07   4.098373  0.396356  -0.280112  -2.643024
# 2000-01-08   4.035274  1.187327  -0.626354  -2.805276
# 2000-01-09   2.995351  1.358176  -0.367052  -4.291214
# 2000-01-10   1.658753  1.823118  -0.488956  -4.888931
# 2000-01-11   3.057209  0.913850   0.967108  -3.838071
# 2000-01-12   2.718432 -0.596310  -1.810985  -4.665497
# 2000-01-13   2.343667 -1.159801  -2.858612  -5.649852
# 2000-01-14   2.755233 -2.949841  -3.647713  -4.424976
# 2000-01-15   4.285017 -3.654578  -3.083526  -4.672579
# 2000-01-16   3.510888 -3.369886  -3.236432  -2.716474
# ...
