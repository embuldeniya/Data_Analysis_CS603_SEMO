# %% [markdown]
# so, let's begin
#
# import the file <span style="background-color: #FFFF00"><b><u>train.csv</u></b></span>
#
# as a reminder:
#
# <b>Data Fields:</b><br/>
# <b>datetime</b> - hourly date + timestamp  <br/>
# <b>season</b> -  1 = spring, 2 = summer, 3 = fall, 4 = winter<br/>
# <b>holiday</b> - whether the day is considered a holiday<br/>
# <b>workingday</b> - whether the day is neither a weekend nor holiday<br/>
# <b>weather</b> - 1: Clear, Few clouds, Partly cloudy, Partly cloudy<br/>
# &emsp;&emsp;&emsp;&emsp;&emsp;2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist<br/>
# &emsp;&emsp;&emsp;&emsp;&emsp;3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds<br/>
# &emsp;&emsp;&emsp;&emsp;&emsp;4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog<br/>
# <b>temp</b> - temperature in Celsius<br/>
# <b>atemp</b> - "feels like" temperature in Celsius<br/>
# <b>humidity</b> - relative humidity<br/>
# <b>windspeed</b> - wind speed<br/>
# <b>casual</b> - number of non-registered user rentals initiated<br/>
# <b>registered</b> - number of registered user rentals initiated<br/>
# <b>count</b> - number of total rentals<br/>

# %%
import csv
import numpy as np
import pandas as pd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# machine learning
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# importing
train_df = pd.read_csv('../term_project/train.csv')
test_df = pd.read_csv('../term_project/test.csv')
combine = [train_df, test_df]

print(train_df.columns.values)
# Out:
# ['datetime' 'season' 'holiday' 'workingday' 'weather' 'temp' 'atemp'
#  'humidity' 'windspeed' 'casual' 'registered' 'count']

# %%
# let's add some auxiliary data
# we can use this later for mapping, re-naming and other stuff
seasons = { 1: 'Spring',
          2: 'Summer',
          3: 'Fall',
          4: 'Winter'}

# %%
# preview the data
train_df.head()
# Out:
#          datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  01-01-11 00:00       1        0           0        1  9.84  14.395
# 1  01-01-11 01:00       1        0           0        1  9.02  13.635
# 2  01-01-11 02:00       1        0           0        1  9.02  13.635
# 3  01-01-11 03:00       1        0           0        1  9.84  14.395
# 4  01-01-11 04:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
# let's see what do we have
train_df.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# ...

# %%
# convert datetime column from object type to datetime type
for dataset in combine:
    dataset['datetime'] = pd.to_datetime(dataset['datetime'])

train_df.info()
print('_'*40)
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
# datetime      10886 non-null datetime64[ns]
# season        10886 non-null int64
# holiday       10886 non-null int64
# workingday    10886 non-null int64
# weather       10886 non-null int64
# temp          10886 non-null float64
# atemp         10886 non-null float64
# humidity      10886 non-null int64
# windspeed     10886 non-null float64
# casual        10886 non-null int64
# registered    10886 non-null int64
# count         10886 non-null int64
# dtypes: datetime64[ns](1), float64(3), int64(8)
# memory usage: 1020.6 KB
# ________________________________________
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6493 entries, 0 to 6492
# Data columns (total 9 columns):
# datetime      6493 non-null datetime64[ns]
# season        6493 non-null int64
# holiday       6493 non-null int64
# workingday    6493 non-null int64
# weather       6493 non-null int64
# ...

# %%
# make sure data conversion was OK
train_df.tail()
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 10881 2012-12-19 19:00:00       4        0           1        1  15.58
# 10882 2012-12-19 20:00:00       4        0           1        1  14.76
# 10883 2012-12-19 21:00:00       4        0           1        1  13.94
# 10884 2012-12-19 22:00:00       4        0           1        1  13.94
# 10885 2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# 10881  19.695        50    26.0027       7         329    336
# 10882  17.425        57    15.0013      10         231    241
# 10883  15.910        61    15.0013       4         164    168
# 10884  17.425        61     6.0032      12         117    129
# 10885  16.665        66     8.9981       4          84     88

# %%
# let's figure out how many holidays we have
train_df[train_df['holiday'] == 1]['holiday'].count() / train_df['holiday'].count() * 100
# Out:
# 2.856880396839978

# %%
# so, closer to 3% of data is weird data

# here will be a good idea to do simple plotting for holidays and then for weekends
# since they will be similar - we will decide to group them together





# anyway, now let's figure out what plays major role
xxx = train_df[['season', 'count']].groupby(['season'], as_index=False).mean().sort_values(by='count', ascending=False)

xxx['weight'] = xxx['count'] / xxx['count'].sum() * 100

xxx['season'] = xxx['season'].map(seasons)

xxx
# Out:
#    season       count     weight
# 2    Fall  234.417124  30.642759
# 1  Summer  215.251372  28.137432
# 3  Winter  198.988296  26.011540
# 0  Spring  116.343261  15.208268

# %% [markdown]
# Plotting - Shows the Bike Demand for Each Season  (Based on initial test data)

# %%
ax = sns.lineplot(x="season", y="count", data=xxx)

# %%
# here will be a good idea to paste cool graph from keggle
# https://www.kaggle.com/h19881812/data-vizualization

# this is in  r language

# %%
# so, Fall = 30.64%, Summer = 28.1#, Winter = 26.0%, Spring = 15.2%

xxx = train_df[['holiday', 'count']].groupby(['holiday'], as_index=False).mean().sort_values(by='count', ascending=False)

xxx['weight'] = xxx['count'] / xxx['count'].sum() * 100

xxx
# Out:
#    holiday       count     weight
# 0        0  191.741655  50.776422
# 1        1  185.877814  49.223578

# %%
xxx2 = xxx.copy()
xxx.groupby(["holiday"])['weight'].size().plot(kind='bar',stacked=True)
plt.ylabel('Weight')
plt.xlabel('Holiday')
plt.title('Holiday')
plt.yticks(np.arange(0,5, 120))
plt.xticks(np.arange(0, 2, 1))
#plt.legend(["Holiday", "Working Day"], loc =2)

plt.show()

# %%
# so, holiday doesn't affect data in any way

# again, good place to insert graph from keggle which shows difference in weekends and weekdays in usage


# just to make sure
xxx = train_df[['workingday', 'count']].groupby(['workingday'], as_index=False).mean().sort_values(by='count', ascending=False)

xxx['weight'] = xxx['count'] / xxx['count'].sum() * 100


xxx
# Out:
#    workingday       count     weight
# 1           1  193.011873  50.590437
# 0           0  188.506621  49.409563

# %%
xxx.groupby(["workingday"])['weight'].size().plot(kind='bar',stacked=True)
plt.ylabel('Weight')
plt.xlabel('Working Data')
plt.title('Working Day')
plt.yticks(np.arange(0,5, 120))
plt.xticks(np.arange(0, 2, 1))
#plt.legend(["Holiday", "Working Day"], loc =2)

plt.show()

# %% [markdown]
# #Plot Correlation for holiday vs working day

# %%
fig,(ax1) = plt.subplots(ncols=1)
fig.set_size_inches(20, 8)
sns.regplot(x="workingday", y="weight", data=xxx,ax=ax1)
sns.regplot(x="holiday", y="weight", data=xxx2,ax=ax1)

# %% [markdown]
# #pair plots visualization all the data

# %%
sns.pairplot(train_df[['temp','atemp','humidity','windspeed','casual','registered']],size=4)
# Out:
# /Users/techyouknow/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Plotting  idea taken from https://github.com/viveksrinivasanss/blogs/blob/master/bike_sharing_demand/.ipynb_checkpoints/eda_%26_ensemble_model-checkpoint.ipynb
# understanding about how data being distrubuted for windspeed and humidty

# %% [markdown]
# Plot - temp vs atemp correlation (separte plot)

# %%
sns.pairplot(train_df[['temp','atemp']],size=2)
# Out:
# /Users/techyouknow/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Plot - temp vs atemp correlation (same plot)

# %%
fig,(ax1) = plt.subplots(ncols=1)
fig.set_size_inches(10, 5)
sns.regplot(x="atemp", y="count", data=train_df,ax=ax1)
sns.regplot(x="temp", y="count", data=train_df,ax=ax1)

# %% [markdown]
# Plot to casual vs registered (separted graphs)

# %%
sns.pairplot(train_df[['casual','registered']],size=2)
# Out:
# /Users/techyouknow/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
#correlating casual and registered users (same plot)
fig,(ax1) = plt.subplots(ncols=1)
fig.set_size_inches(10, 5)
sns.regplot(x="casual", y="count", data=train_df,ax=ax1)
sns.regplot(x="registered", y="count", data=train_df,ax=ax1)

# %%
# now, as agreed, I'm dropping wheather, atemp, casual & registered

# as a reminder - it will be a good idea to insert some charts before that will support our idea
# something like relation temp to atemp and charts with weather playing not a significant role (especially bad weather)



train_df = train_df.drop(['weather', 'atemp', 'casual', 'registered'], axis=1)
test_df = test_df.drop(['weather', 'atemp'], axis=1)

train_df.head()
# Out:
#              datetime  season  holiday  workingday  temp  humidity  windspeed  \
# 0 2011-01-01 00:00:00       1        0           0  9.84        81        0.0
# 1 2011-01-01 01:00:00       1        0           0  9.02        80        0.0
# 2 2011-01-01 02:00:00       1        0           0  9.02        80        0.0
# 3 2011-01-01 03:00:00       1        0           0  9.84        75        0.0
# 4 2011-01-01 04:00:00       1        0           0  9.84        75        0.0
#
#    count
# 0     16
# 1     40
# 2     32
# 3     13
# 4      1

# %% [markdown]
# Plot for understanding  how  the data distrubtion for WindSpeed, Humdity and Temp

# %%
fig,(ax1,ax2) = plt.subplots(ncols=2)
fig.set_size_inches(30, 5)
sns.regplot(x="windspeed", y="count", data=train_df,ax=ax1)
sns.regplot(x="humidity", y="count", data=train_df,ax=ax2)

# %%
fig,(ax1) = plt.subplots(ncols=1)
fig.set_size_inches(20, 5)
sns.regplot(x="temp", y="count", data=train_df,ax=ax1)

# %%
# converting windspeed from numerical to categorical data
for dataset in combine:
    dataset.loc[ dataset['windspeed'] <= 6, 'windspeed'] = 0
    dataset.loc[(dataset['windspeed'] > 6) & (dataset['windspeed'] <= 11), 'windspeed'] = 1
    dataset.loc[(dataset['windspeed'] > 11) & (dataset['windspeed'] <= 16), 'windspeed'] = 2
    dataset.loc[ dataset['windspeed'] > 16, 'windspeed'] = 3

    dataset['windspeed'] = dataset.windspeed.astype(int)
    
test_df.head()
# Out:
#              datetime  season  holiday  workingday   temp  humidity  windspeed
# 0 2011-01-20 00:00:00       1        0           1  10.66        56    26.0027
# 1 2011-01-20 01:00:00       1        0           1  10.66        56     0.0000
# 2 2011-01-20 02:00:00       1        0           1  10.66        56     0.0000
# 3 2011-01-20 03:00:00       1        0           1  10.66        56    11.0014
# 4 2011-01-20 04:00:00       1        0           1  10.66        56    11.0014

# %%
# ok, this is not working
# any ideas?

# I will do this manually then
train_df.loc[ train_df['windspeed'] <= 6, 'windspeed'] = 0
train_df.loc[(train_df['windspeed'] > 6) & (train_df['windspeed'] <= 11), 'windspeed'] = 1
train_df.loc[(train_df['windspeed'] > 11) & (train_df['windspeed'] <= 16), 'windspeed'] = 2
train_df.loc[ train_df['windspeed'] > 16, 'windspeed'] = 3

train_df['windspeed'] = train_df.windspeed.astype(int)

test_df.loc[ test_df['windspeed'] <= 6, 'windspeed'] = 0
test_df.loc[(test_df['windspeed'] > 6) & (test_df['windspeed'] <= 11), 'windspeed'] = 1
test_df.loc[(test_df['windspeed'] > 11) & (test_df['windspeed'] <= 16), 'windspeed'] = 2
test_df.loc[ test_df['windspeed'] > 16, 'windspeed'] = 3

test_df['windspeed'] = test_df.windspeed.astype(int)
    
train_df.head()
# Out:
#              datetime  season  holiday  workingday  temp  humidity  windspeed  \
# 0 2011-01-01 00:00:00       1        0           0  9.84        81          0
# 1 2011-01-01 01:00:00       1        0           0  9.02        80          0
# 2 2011-01-01 02:00:00       1        0           0  9.02        80          0
# 3 2011-01-01 03:00:00       1        0           0  9.84        75          0
# 4 2011-01-01 04:00:00       1        0           0  9.84        75          0
#
#    count
# 0     16
# 1     40
# 2     32
# 3     13
# 4      1

# %%
# now let me try and do the humidity

# nope, still not working. BUT WHY!!!!
train_df.loc[(train_df['humidity'] < 20), 'humidity'] = 0
train_df.loc[(train_df['humidity'] >= 20) & (train_df['humidity'] <= 80), 'humidity'] = 1
train_df.loc[(train_df['humidity'] > 80), 'humidity'] = 2
train_df['humidity'] = train_df.humidity.astype(int)

test_df.loc[(test_df['humidity'] < 20), 'humidity'] = 0
test_df.loc[(test_df['humidity'] >= 20) & (test_df['humidity'] <= 80), 'humidity'] = 1
test_df.loc[(test_df['humidity'] > 80), 'humidity'] = 2
test_df['humidity'] = test_df.humidity.astype(int)
    
train_df.head()
# Out:
#              datetime  season  holiday  workingday  temp  humidity  windspeed  \
# 0 2011-01-01 00:00:00       1        0           0  9.84         2          0
# 1 2011-01-01 01:00:00       1        0           0  9.02         1          0
# 2 2011-01-01 02:00:00       1        0           0  9.02         1          0
# 3 2011-01-01 03:00:00       1        0           0  9.84         1          0
# 4 2011-01-01 04:00:00       1        0           0  9.84         1          0
#
#    count
# 0     16
# 1     40
# 2     32
# 3     13
# 4      1

# %%
# and now the temperature
# again, step by step

train_df.loc[(train_df['temp'] < 8), 'temp'] = 0
train_df.loc[(train_df['temp'] >= 8) & (train_df['temp'] < 12), 'temp'] = 1
train_df.loc[(train_df['temp'] >= 12) & (train_df['temp'] < 16), 'temp'] = 2
train_df.loc[(train_df['temp'] >= 16) & (train_df['temp'] < 24), 'temp'] = 3
train_df.loc[(train_df['temp'] >= 24) & (train_df['temp'] < 28), 'temp'] = 4
train_df.loc[(train_df['temp'] >= 28) & (train_df['temp'] < 32), 'temp'] = 5
train_df.loc[(train_df['temp'] >= 32), 'temp'] = 6
train_df['temp'] = train_df.temp.astype(int)

test_df.loc[(test_df['temp'] < 8), 'temp'] = 0
test_df.loc[(test_df['temp'] >= 8) & (test_df['temp'] < 12), 'temp'] = 1
test_df.loc[(test_df['temp'] >= 12) & (test_df['temp'] < 16), 'temp'] = 2
test_df.loc[(test_df['temp'] >= 16) & (test_df['temp'] < 24), 'temp'] = 3
test_df.loc[(test_df['temp'] >= 24) & (test_df['temp'] < 28), 'temp'] = 4
test_df.loc[(test_df['temp'] >= 28) & (test_df['temp'] < 32), 'temp'] = 5
test_df.loc[(test_df['temp'] >= 32), 'temp'] = 6
test_df['temp'] = test_df.temp.astype(int)

train_df.head()
# Out:
#              datetime  season  holiday  workingday  temp  humidity  windspeed  \
# 0 2011-01-01 00:00:00       1        0           0     1         2          0
# 1 2011-01-01 01:00:00       1        0           0     1         1          0
# 2 2011-01-01 02:00:00       1        0           0     1         1          0
# 3 2011-01-01 03:00:00       1        0           0     1         1          0
# 4 2011-01-01 04:00:00       1        0           0     1         1          0
#
#    count
# 0     16
# 1     40
# 2     32
# 3     13
# 4      1

# %%
# and now let us split it to 2 DataFrames
# holidays and weekends will go to train_we_df, and workdays to train_wd_df

train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 8 columns):
# datetime      10886 non-null datetime64[ns]
# season        10886 non-null int64
# holiday       10886 non-null int64
# workingday    10886 non-null int64
# temp          10886 non-null int64
# humidity      10886 non-null int64
# windspeed     10886 non-null int64
# count         10886 non-null int64
# dtypes: datetime64[ns](1), int64(7)
# memory usage: 680.5 KB

# %%
train_wd_df = train_df[train_df['workingday'] == 1]

train_wd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7412 entries, 47 to 10885
# Data columns (total 8 columns):
# datetime      7412 non-null datetime64[ns]
# season        7412 non-null int64
# holiday       7412 non-null int64
# workingday    7412 non-null int64
# temp          7412 non-null int64
# humidity      7412 non-null int64
# windspeed     7412 non-null int64
# count         7412 non-null int64
# dtypes: datetime64[ns](1), int64(7)
# memory usage: 521.2 KB

# %%
train_we_df = train_df[train_df['workingday'] == 0]

train_we_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3474 entries, 0 to 10813
# Data columns (total 8 columns):
# datetime      3474 non-null datetime64[ns]
# season        3474 non-null int64
# holiday       3474 non-null int64
# workingday    3474 non-null int64
# temp          3474 non-null int64
# humidity      3474 non-null int64
# windspeed     3474 non-null int64
# count         3474 non-null int64
# dtypes: datetime64[ns](1), int64(7)
# memory usage: 244.3 KB

# %%
# 7412 + 3474 = 10886, so we're good

# now we have to do some plotting to support our claim that separation was a right thing to do
# aaaaand we're done

# %%
#Before modeling, lets check what we finally have in both train.csv and test.csv files
#first on train.csv file
train_df.info()
#then on test.csv file
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 8 columns):
# datetime      10886 non-null datetime64[ns]
# season        10886 non-null int64
# holiday       10886 non-null int64
# workingday    10886 non-null int64
# temp          10886 non-null int64
# humidity      10886 non-null int64
# windspeed     10886 non-null int64
# count         10886 non-null int64
# dtypes: datetime64[ns](1), int64(7)
# memory usage: 680.5 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6493 entries, 0 to 6492
# Data columns (total 7 columns):
# datetime      6493 non-null datetime64[ns]
# season        6493 non-null int64
# holiday       6493 non-null int64
# workingday    6493 non-null int64
# temp          6493 non-null int64
# humidity      6493 non-null int64
# windspeed     6493 non-null int64
# dtypes: datetime64[ns](1), int64(6)
# memory usage: 355.2 KB

# %% [markdown]
# To make both csv file consistent, we will add count in test.csv file and also will split date to year, month, hour and day, so we can easily enter those in our algorthms

# %%
test_df['count'] = np.nan
train_df['year'] = train_df['datetime'].dt.year
train_df['month'] = train_df['datetime'].dt.month
train_df['hour'] = train_df['datetime'].dt.hour
train_df['day'] = train_df['datetime'].dt.dayofweek

test_df['year'] = test_df['datetime'].dt.year
test_df['month'] = test_df['datetime'].dt.month
test_df['hour'] = test_df['datetime'].dt.hour
test_df['day'] = test_df['datetime'].dt.dayofweek

# %% [markdown]
# From our decisions as explained above after adding and removing features, we have selected workingday, temp, year, month, hour and day for predictions and we will select x axis and y-axis respectively. x-axis are the features selected and y-axis is the count that we are looking to predict

# %%
selected_features =['workingday', 'hour', 'temp', 'humidity', 'windspeed']

#select x, y axis for train data
x_original_train = train_df[selected_features]
y_original_train = train_df['count']

#select x, y axis for test data
x_test = test_df[selected_features]
y_test = test_df['count']

# %% [markdown]
# Since dataset could be huge and we are not sure which model is best in our situation, lets first create portion of entire set for validations, which will give us the best model options. Here we are going to choose 25% of entrie dataset for validation and random_state is selected at 300.

# %%
#validating tests on portion of entire set of data we have
x_train, x_valid, y_train, y_valid = train_test_split(x_original_train, y_original_train, test_size = 0.25, random_state = 300)
x_train.head()
# Out:
#       workingday  hour  temp  humidity  windspeed
# 3216           1    22     4         2          1
# 1268           1    16     3         1          3
# 9360           1     9     4         1          1
# 7495           1    16     4         1          3
# 2464           1    14     6         1          0

# %%
x_valid.head()
# Out:
#       workingday  hour  temp  humidity  windspeed
# 6200           1    14     3         1          2
# 2779           0    17     6         1          0
# 8668           1    13     6         1          3
# 570            0    22     1         1          0
# 6527           1     5     3         1          3

# %% [markdown]
# Now as we are provided with the RMSLE (Root Mean Squared Logarithmic Error) in the Kaggle, we will define this as a function:

# %%
def RMSLE(predictions, realizations):
    predictions_use = predictions.clip(0)
    rmsle = np.sqrt(np.mean(np.array(np.log(predictions_use+1)-np.log(realizations+1))**2))
    return rmsle

# %% [markdown]
# Finally its time to check our first model - <b>Regression Tree</b> and we are going to use DecisionTreeRegressor with min_samples_split of 25 and random_state 300 and display the feature importance with this model

# %%
regression_tree =DecisionTreeRegressor(min_samples_split = 25, random_state = 300)
regression_tree_model = regression_tree.fit(x_train, y_train)
regression_tree_prediction = regression_tree_model.predict(x_valid)

#checking which feature is important with this model.
pd.DataFrame(regression_tree_model.feature_importances_, index=selected_features)
# Out:
#                    0
# workingday  0.064772
# hour        0.741052
# temp        0.144638
# humidity    0.037977
# windspeed   0.011561

# %% [markdown]
# Result shows that hour feature is important as compared to other features. Now we can actually plot the Predicted Vs Actual count using Regress Tree model as below:

# %%
plt.figure(figsize=(6,6))
plt.scatter(regression_tree_prediction, y_valid, s=0.2)
plt.xlim(-100, 1200)
plt.ylim(-100, 1200)
plt.plot([-100, 1200], [-100, 1200], color='r', linestyle='-', linewidth=2)
plt.suptitle('Predicted Vs Actual count - Regression Tree', fontsize=20)
plt.xlabel('Regression Tree Prediction', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.show()

# %% [markdown]
# Finally we will use the RMSLE function to evaluation this model.

# %%
RMSLE(regression_tree_prediction, y_valid)
# Out:
# 0.49659000628679756

# %% [markdown]
# Since this is our first model, we don't have anything to compare with, so lets compare this with a second model - <b>Random Forest</b> and we can decide which one is better. Note: Lower RMSLE value is better.

# %%
random_forest = RandomForestRegressor(n_estimators = 500, max_features=4, min_samples_leaf=5, random_state = 300)
random_forest_model = random_forest.fit(x_train, y_train)
random_forest_prediction = random_forest_model.predict(x_valid)

pd.DataFrame(random_forest_model.feature_importances_, index=selected_features)
# Out:
#                    0
# workingday  0.084554
# hour        0.710203
# temp        0.151118
# humidity    0.035367
# windspeed   0.018758

# %% [markdown]
# This model also indicates that hour is the important feature in this modeling too like in Regression Tree model. We can show this modeling in plot too to compare predicted vs actual count.

# %%
plt.figure(figsize=(6,6))
plt.scatter(random_forest_prediction, y_valid, s=0.2)
plt.xlim(-100, 1200)
plt.ylim(-100, 1200)
plt.plot([-100, 1200], [-100, 1200], color='r', linestyle='-', linewidth=2)
plt.suptitle('Predicted Vs Actual count - Random Forest', fontsize=20)
plt.xlabel('Random Forest Prediction', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.show()

# %% [markdown]
# Lets now check the RMSLE value for this model.

# %%
RMSLE(random_forest_prediction, y_valid)
# Out:
# 0.4932116472002411

# %% [markdown]
# Even though difference is not big in our scenarios, still the RMSLE value for Random Forest modeling is lower compared to Regression Tree, so we choose this modeling for our final submission. Now we finally use the Random Forest Modeling to our actual test dataset and predict the total count. Please also note that we have rounded this number to closest integer.

# %%
random_forest_model_train = random_forest.fit(x_original_train, y_original_train)
random_forest_model_prediction_test = random_forest_model_train.predict(x_test)
random_forest_prediction_test_clipped = pd.Series(np.round(random_forest_model_prediction_test.clip(0)))

# %% [markdown]
# The predicted count is stored as Series so far at this stage and now we need to write the series to a csv file in the submission format we are provided. We will use the submissionsample.csv file and create a finalSubmission.csv file.

# %%
sample_submission = pd.read_csv("../term_project/sampleSubmission.csv")
sample_submission.head()
random_forest_submission = sample_submission
random_forest_submission['count'] = random_forest_prediction_test_clipped
random_forest_submission.to_csv("../term_project/finalSubmission.csv", index=False)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-7c87b6f4e9ab> in <module>
# ----> 1 combine["windspeed"]
#
# TypeError: list indices must be integers or slices, not str
