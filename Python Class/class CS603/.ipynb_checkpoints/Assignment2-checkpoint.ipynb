# %%
import numpy as np 
from datetime import datetime

file = "/Users/techyouknow/Desktop/Python Class/SP500.csv"


date =np.loadtxt(file,  delimiter = "," , skiprows=1, usecols=(0) , dtype=np.datetime64)

value=np.loadtxt(file,  delimiter = "," , skiprows=1, usecols=(1,2,3,4,5,6) , dtype=np.float64)


#No1 daily gain from open & close  
gain = [i[0] - i[3] for i in value]

print("** highest daily gain value  & date **")
print(date[np.argmax(gain, axis=0)])
print(np.amax(gain, axis=0))


print("** lowest daily gain value & date **")
print(date[np.argmin(gain, axis=0)])
print(np.amin(gain, axis=0))


#No2 volume & date
print("** daily transcation and date  **")
print(int(np.amax(value, axis=0)[5]))
print(date[(np.argmax(value, axis=0)[5])])

print("")

#No3 monthly Avg & open price range in 2017/2018  

def monthlyAvg(t1,x):
    s= []
    for x in t1:
        s = x
    
    mon = []    
    for i in s:
        mon.append(value [i]) 
    
    mon = np.array (mon)

    print ("{0} - {1} \n".format(date[s[0]],date[s[-1]]))
  
    
    print ("open average= ",np.mean(mon[:,0] ))
    print ("high average= ",np.mean(mon[:,1] ))
    print ("low average= ",np.mean(mon[:,2] ))
    print ("close average= ",np.mean(mon[:,3] ))
    print ("adjclose average= ",np.mean(mon[:,4] ))
    print ("volume average= ",np.mean(mon[:,5] ))  
    print ("\n === Open Price Range === ")
    print ("{0} -  {1}".format(np.min(mon[:,0]),np.max(mon[:,0])))
    print ("\n")


month = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug","Sep", "Oct", "Nov","Dec"]  

print ("Months between  2017/2018 \n")
for i in range (1,13):
    if (i == 12):
        print (month [i-1])
        t1 = np.where(np.logical_and(date> np.datetime64(datetime(2017,i,1)),date< np.datetime64(datetime(2018,1,1))))
        monthlyAvg(t1,i)
    else:
        print (month [i-1])
       
        t1 = np.where(np.logical_and(date> np.datetime64(datetime(2017,i,1)),date< np.datetime64(datetime(2017,i+1,1))))
        monthlyAvg(t1,i)
# Out:
# ** highest daily gain value  & date **
# 2018-02-08
# 104.01000999999997
# ** lowest daily gain value & date **
# 2008-10-28
# -91.59002699999996
# ** daily transcation and date  **
# 11456230000
# 2008-10-10
#
# Months between  2017/2018
#
# Jan
# 2017-01-03 - 2017-01-31
#
# open average=  2273.5319704000003
# high average=  2279.3645142
# low average=  2266.7555055
# close average=  2275.1159789
# adjclose average=  2275.1159789
# volume average=  3524159000.0
#
#  === Open Price Range ===
# 2251.570068 -  2299.02002
#
#
# Feb
# 2017-02-02 - 2017-02-28
#
# open average=  2327.8072373333334
# high average=  2335.210001666667
# low average=  2323.902235222222
# close average=  2332.708347
# adjclose average=  2332.708347
# volume average=  3624767222.2222223
#
#  === Open Price Range ===
# 2276.689941 -  2367.5
#
#
# Mar
# 2017-03-02 - 2017-03-31
#
# open average=  2366.2659246363637
# high average=  2372.7100164999997
# low average=  2358.0899658636367
# close average=  2365.497725136364
# adjclose average=  2365.497725136364
# volume average=  3509208636.3636365
#
#  === Open Price Range ===
# 2329.110107 -  2394.75
#
#
# Apr
# 2017-04-03 - 2017-04-28
#
# open average=  2360.150005052632
# high average=  2367.1747404736843
# low average=  2352.324719842105
# close average=  2359.3094545789477
# adjclose average=  2359.3094545789477
# volume average=  3435035263.1578946
#
#  === Open Price Range ===
# 2332.620117 -  2393.679932
#
#
# May
# 2017-05-02 - 2017-05-31
#
# open average=  2394.754289809524
# high average=  2399.743826761905
# low average=  2388.7975958095235
# close average=  2395.6799665238095
# adjclose average=  2395.6799665238095
# volume average=  3638472857.142857
#
#  === Open Price Range ===
# 2354.689941 -  2415.629883
#
#
# Jun
# 2017-06-02 - 2017-06-30
#
# open average=  2435.589971619048
# high average=  2440.8652110000003
# low average=  2426.896670333333
# close average=  2434.1723749047624
# adjclose average=  2434.1723749047624
# volume average=  3673588095.2380953
#
#  === Open Price Range ===
# 2424.139893 -  2450.659912
#
#
# Jul
# 2017-07-03 - 2017-07-31
#
# open average=  2453.0394897999995
# high average=  2458.22401115
# low average=  2447.26398925
# close average=  2454.1025025
# adjclose average=  2454.1025025
# volume average=  3158470000.0
#
#  === Open Price Range ===
# 2413.52002 -  2482.76001
#
#
# Aug
# 2017-08-02 - 2017-08-31
#
# open average=  2455.8249623636366
# high average=  2462.985895409091
# low average=  2448.4963711363635
# close average=  2455.3082053181815
# adjclose average=  2455.3082053181815
# volume average=  3052507727.2727275
#
#  === Open Price Range ===
# 2425.5 -  2480.379883
#
#
# Sep
# 2017-09-05 - 2017-09-29
#
# open average=  2492.222630684211
# high average=  2497.0410670526317
# low average=  2486.9620939473684
# close average=  2493.6984605789476
# adjclose average=  2493.6984605789476
# volume average=  3348802631.5789475
#
#  === Open Price Range ===
# 2462.25 -  2509.959961
#
#
# Oct
# 2017-10-02 - 2017-10-31
#
# open average=  2555.807273136363
# high average=  2560.4277230909092
# low average=  2551.0090998181813
# close average=  2556.99727
# adjclose average=  2556.99727
# volume average=  3221435000.0
#
#  === Open Price Range ===
# 2521.199951 -  2578.080078
#
#
# Nov
# 2017-11-02 - 2017-11-30
#
# open average=  2590.6609741
# high average=  2597.88146975
# low average=  2585.5275024
# close average=  2594.31801765
# adjclose average=  2594.31801765
# volume average=  3468004000.0
#
#  === Open Price Range ===
# 2569.449951 -  2633.929932
#
#
# Dec
# 2017-12-04 - 2017-12-29
#
# open average=  2667.173673947369
# high average=  2673.5357602105264
# low average=  2661.2557822105264
# close average=  2665.504767105263
# adjclose average=  2665.504767105263
# volume average=  3226782631.5789475
#
#  === Open Price Range ===
# 2626.23999 -  2692.709961

# %%
# return tuples contains the dates range 
t1 = np.where(np.logical_and(date> np.datetime64(datetime(2017,1,1)),date< np.datetime64(datetime(2017,2,1))))





s= []
for x in t1:
    s = x
    
'''
print (s[0]) 
print (len(s))    
 ''' 
    
mon = []    
for i in s:
    mon.append(value [i]) 
    

mon = np.array (mon)
#for i in range:
    #print( mon [:,5])


    
print ("jan 2017 open average= ",np.mean(mon[:,0] ))
print ("jan 2017 high average= ",np.mean(mon[:,1] ))
print ("jan 2017 low average= ",np.mean(mon[:,2] ))
print ("jan 2017 close average= ",np.mean(mon[:,3] ))
print ("jan 2017 adjclose average= ",np.mean(mon[:,4] ))
print ("jan 2017 volume average= ",np.mean(mon[:,5] ))    
# open 

#int_val = np.copy (np.array (mon).astype(int))

#print (int_val)




#print (np.mean(int_val[:][0]) )

# %%
print (date[:2])
print (value[:1])

# %%
import numpy as np
import csv
import datetime as dt
# read everything from the SP500.csv
csvfile = "/Users/techyouknow/Desktop/Python Class/SP500.csv"
# auxiliary list to hold all the values from CSV file
values_lst = []
dates_lst = []
# read the file line by line
with open(csvfile) as file:
    lst = [line.rstrip().split(",") for line in file]
    for line in lst[1:]:
        # append each value to a list
        dates_lst.append(line[0])
        #dates_lst.append([dt.datetime.strptime(line[0],"%Y-%m-%d" ).date])
        
        for item in line[1:]: values_lst.append(item)
    
# create NumPy 2D array with 7 columns and god knows how many rows
mtrx = np.array(values_lst).astype(np.float).reshape(int(len(values_lst) / 6), 6)





print(int(np.amax(mtrx, axis=0)[5]))
print(dates_lst[(np.argmax(mtrx, axis=0)[5])])

# %%
# convert date_list  into date format 
date = []
for x in dates_lst:
    print (x)
    date.append([dt.datetime.strptime(x,"%Y-%m-%d" ).date])

# %%
import numpy as np
from datetime import datetime
wind = np.loadtxt('/Users/techyouknow/Desktop/Python Class/SP500.csv', delimiter=",", usecols=(0), dtype=object,converters={0: lambda x: datetime.strptime(x, "%Y-%m-%d ")})
